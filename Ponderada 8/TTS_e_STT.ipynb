# %% [markdown]
# STT

# %%
pip install -U openai-whisper

# %%
import argparse
import whisper

def main():

    model = whisper.load_model("medium")
    result = model.transcribe("./calma.mp3")
    print(result["text"])

if __name__ == "__main__":
    main()

# %% [markdown]
# TTS

# %%
pip install git+https://github.com/suno-ai/bark.git

# %%
pip install simpleaudio

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
import simpleaudio as sa

from IPython.display import Audio

# download and load all models
preload_models()

# generate audio from text
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [laughs]
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)

# %% [markdown]
# # Ponderada

# %%
pip install git+https://github.com/suno-ai/bark.git

# %%
pip install -U openai-whisper

# %%
import whisper

def transcribe_audio(file_path):
    # Carregar o modelo Whisper
    model = whisper.load_model("medium")

    # Carregar o arquivo de áudio
    audio = whisper.load_audio(file_path)

    # Transcrever o áudio diretamente para inglês
    result = model.transcribe(audio, language='en')

    # Extrair e retornar o texto transcrito
    text = result['text']
    return text

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models

def synthesize_audio(text):
    preload_models()
    audio_array = generate_audio(text)
    return audio_array

# %%
def save_text_to_file(text, file_name):
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(text)

# %%
from scipy.io.wavfile import write as write_wav

def save_speech_to_file(audio_array, file_name):
    write_wav(file_name, SAMPLE_RATE, audio_array)
    
    return

# %%
import os 

os.listdir()

# %%
os.getcwd()

# %%
def main():
    # Obter caminho do arquivo de áudio
    audio_path = input("Caminho: ")
    file_name = input("Nome para salvar: ")

    # Transcrever áudio para texto
    transcribed_text = transcribe_audio(audio_path)
    print("Texto Transcrito:", transcribed_text)

    save_text_to_file(transcribed_text, file_name + ".txt")  # Salvando o texto transcrita
    print(f"Texto gerado salvo!")
    
    # Sintetizar áudio da tradução
    audio = synthesize_audio(transcribed_text)
    
    save_speech_to_file(audio, file_name + ".wav")
    print(f"Áudio gerado salvo!")

if __name__ == "__main__":
    main()
